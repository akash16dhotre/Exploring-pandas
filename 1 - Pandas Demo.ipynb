# %% [markdown]
# # A project in Python to understand the pandas library and  play around with the functionality

# %% [markdown]
# In computer programming, pandas is a software library written for the Python programming language for data manipulation and analysis. pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool.

# %%
import pandas as pd # Import pandas library

# %%
df = pd.read_csv('survey_results_public.csv') # Read file
schema_df = pd.read_csv('survey_results_schema.csv') # Read file

# %%
pd.set_option('display.max_columns', 85) # This displays all 85 column above
pd.set_option('display.max_rows', 85)  # Display all 85 rows

# %%
df.head() # Read first five items in dataframe. Dataframe are the rows and coloumn OR container of series. They are the backbone of pandas!
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.info() # This is a method. SO, ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.shape # This is attribute not function. So, no ()
# Out:
# (88883, 85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.columns # Display all columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Hobbyist'] # Get series of all responses with head & tail of the data
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %% [markdown]
# Let us see how powerful pandas is. From the above output let us see how many answered 'yes' and 'no'.
# If we use regular python we may have written loop/function.
# But, pandas have everything that is needed :)

# %%
df['Hobbyist'].value_counts() # We will see this in future tutorials
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
# Let us grab rows using loc
df.loc[[0,1,2],'Hobbyist'] # This is 1-3 person's response; It is case sensitive 'Hobbyist'
# Out:
# 0    Yes
# 1     No
# 2    Yes
# Name: Hobbyist, dtype: object

# %%
df.loc[0:2,'Hobbyist': 'Employment'] # Slicing; To select more data
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %% [markdown]
# # 2) Set, Reset and Sort Index

# %%
df_1 = pd.read_csv('survey_results_public.csv', index_col='Respondent') # Read file
schema_df_1 = pd.read_csv('survey_results_schema.csv', index_col='Column') # Read file

# %%
df_1.head() # We see that the Respondant has become the index
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
schema_df_1.head() # We see that the index has changed
# Out:
#                                                   QuestionText
# Column
# Respondent   Randomized respondent ID number (not in order ...
# MainBranch   Which of the following options best describes ...
# Hobbyist                               Do you code as a hobby?
# OpenSourcer        How often do you contribute to open source?
# OpenSource   How do you feel about the quality of open sour...

# %%
schema_df_1.loc['MgrIdiot','QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df_1.sort_index(ascending=False, inplace=True) # Sort index alphabetically; INPLACE = TRUE will set the sort to be permanent

# %% [markdown]
# # 3) Filtering: Using Conditionals to Filter Rows and Columns

# %% [markdown]
# We will use filter to calculate salary. Locate salary

# %%
high_salary = (df['ConvertedComp'] > 70000) # ConvertedComp is the Salary
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
# Now if we want to check the result for multiple countrie >> Implementing OR condition will be complex
# Then, just do this
countries = ['United States', 'India', 'United Kingdom', 'Germany', 'Canada']
filt_country = df['Country'].isin(countries) # Pick country that isin countries

# %%
df.loc[filt_country, 'Country']
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 45008, dtype: object

# %%
# df['LanguageWorkedWith']

# %% [markdown]
# Let us say we want to filter languages that are in the above table

# %%
filt_lang = df['LanguageWorkedWith'].str.contains('Python', na=False) # For this column, we are asking if the string contains Python.

# %%
df.loc[filt_lang, 'LanguageWorkedWith']
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %% [markdown]
# # 4) Updating Rows and Columns - Modifying Data Within DataFrames

# %%
# Let us rename ConvertedComp > Salary!
df.rename(columns = {'ConvertedComp': 'SalaryUSD'}, inplace=True)

# %%
df['SalaryUSD']
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: SalaryUSD, Length: 88883, dtype: float64

# %%
# Let us collect all yes from Hobbyist convert them to -----> boolean true
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].replace({'Yes' : 'True', 'No': 'False'})
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 88878     True
# 88879    False
# 88880    False
# 88881    False
# 88882     True
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].replace({'Yes' : 'True', 'No': 'False'}) # We replace the values

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code     True
# 1               2             I am a student who is learning to code    False
# 2               3  I am not primarily a developer, but I write co...     True
# 3               4                     I am a developer by profession    False
# 4               5                     I am a developer by profession     True
# ...           ...                                                ...      ...
# 88878       88377                                                NaN     True
# 88879       88601                                                NaN    False
# 88880       88802                                                NaN    False
# 88881       88816                                                NaN    False
# 88882       88863                                                NaN     True
#
# ...

# %% [markdown]
# # 6) Sorting Data

# %%
# We sort:
# Country => ascending = True (Alphabetical country)
#  SalaryUSD => ascending = False (Max to low salary)
df.sort_values(by=['Country','SalaryUSD'], ascending=[True, False], inplace = True)
df[['Country', 'SalaryUSD']].head(10)
# Out:
#            Country  SalaryUSD
# 62723  Afghanistan  1000000.0
# 50172  Afghanistan   153216.0
# 39018  Afghanistan    19152.0
# 58082  Afghanistan    17556.0
# 7056   Afghanistan    14364.0
# 22327  Afghanistan     7980.0
# 48122  Afghanistan     4464.0
# 10697  Afghanistan     3996.0
# 8112   Afghanistan     1596.0
# 29560  Afghanistan     1116.0

# %% [markdown]
# Let us calculate 10 largest salary

# %%
df['SalaryUSD'].nlargest(10) # This is pretty high; let us see if these people are developer in which language
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10,'SalaryUSD') # nlargest can be
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession     True
# 87353       87896                     I am a developer by profession     True
# 21895       22013                     I am a developer by profession     True
# 28080       28243                     I am a developer by profession     True
# 72274       72732  I am not primarily a developer, but I write co...    False
# 77665       78151                     I am a developer by profession     True
# 79701       80200                     I am a developer by profession     True
# 51798       52132                     I am a developer by profession     True
# 75088       75561                     I am a developer by profession     True
# 32056       32250                     I am a developer by profession     True
#
#                                              OpenSourcer  \
# ...

# %% [markdown]
# # 6) Grouping and Aggregating - Analyzing and Exploring Your Data

# %% [markdown]
# Mean, median, mode are aggregate functions

# %%
df['SalaryUSD'].head(15)
# Out:
# 62723    1000000.0
# 50172     153216.0
# 39018      19152.0
# 58082      17556.0
# 7056       14364.0
# 22327       7980.0
# 48122       4464.0
# 10697       3996.0
# 8112        1596.0
# 29560       1116.0
# 719            0.0
# 28470          0.0
# 6391           NaN
# 7323           NaN
# 12253          NaN
# Name: SalaryUSD, dtype: float64

# %%
df['SalaryUSD'].median() # calculates median of SalaryUSD
# Out:
# 57287.0

# %%
df.median() # Grab all median values
# Out:
# Respondent     44442.0
# CompTotal      62000.0
# SalaryUSD      57287.0
# WorkWeekHrs       40.0
# CodeRevHrs         4.0
# Age               29.0
# dtype: float64

# %%
df.describe() # 50% is median value
# Out:
#          Respondent     CompTotal     SalaryUSD   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04  5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11  1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13  2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00  0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04  2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04  5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05  1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16  2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df['SalaryUSD'].median() # Only 57287 people answered the question
# Out:
# 57287.0

# %%
df['Hobbyist']
# Out:
# 62723     True
# 50172     True
# 39018     True
# 58082     True
# 7056      True
#          ...
# 88873    False
# 88874    False
# 88879    False
# 88880    False
# 88881    False
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df['Hobbyist'].value_counts() # Gives how maany people answered and how many did not
# Out:
# True     71257
# False    17626
# Name: Hobbyist, dtype: int64

# %%
df['SocialMedia']
# Out:
# 62723    I don't use social media
# 50172                    WhatsApp
# 39018                    Facebook
# 58082                    Facebook
# 7056                    Instagram
#                    ...
# 88873                         NaN
# 88874                         NaN
# 88879                         NaN
# 88880                         NaN
# 88881                         NaN
# Name: SocialMedia, Length: 88883, dtype: object

# %%
df['Country'].value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Tonga                        1
# Brunei Darussalam            1
# Saint Kitts and Nevis        1
# Dominica                     1
# Niger                        1
# Name: Country, Length: 179, dtype: int64

# %%
# Let us spliit the countries
# The below objectt contains group. It consists variable
country_group = df.groupby(['Country'])

# %%
country_group.get_group('India')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 21895       22013                     I am a developer by profession     True
# 28080       28243                     I am a developer by profession     True
# 72274       72732  I am not primarily a developer, but I write co...    False
# 16703       16793                     I am a developer by profession     True
# 52225       52561                     I am a developer by profession     True
# ...           ...                                                ...      ...
# 88808       77339                                                NaN     True
# 88825       79795                                                NaN     True
# 88852       83862                                                NaN     True
# 88853       84299                                                NaN     True
# 88864       86012                                                NaN     True
#
# ...

# %%
filt = df['Country']=='India' # Checking countrywise
df.loc[filt]['SocialMedia'].value_counts() # We can see that whatsapp came first and then Youtube, Linked etc
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
# Normalize= True gives % result
country_group['SocialMedia'].value_counts(normalize=True).loc['Russian Federation'] # Russia is called Russian Federation in this survey
# Out:
# SocialMedia
# VK ВКонта́кте               0.303571
# YouTube                     0.207418
# I don't use social media    0.106456
# Reddit                      0.096154
# Twitter                     0.089286
# Instagram                   0.064560
# WhatsApp                    0.061813
# Facebook                    0.046016
# LinkedIn                    0.024038
# Snapchat                    0.000687
# Name: SocialMedia, dtype: float64

# %%
country_group['SalaryUSD'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_group['SalaryUSD'].agg(['median','mean']).loc['Canada']
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')

#  This shows True for people who have worked with Python with other other languages; and false who is not working with Python
# Out:
# 21895     True
# 28080     True
# 72274     True
# 16703     True
# 52225    False
#          ...
# 88808    False
# 88825     True
# 88852    False
# 88853     True
# 88864    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum() # Total people in India entered Python
# Out:
# 3105

# %%
# We can apply a function and run it; We use lambda function
country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Lambda is going to be a series and we pass in a function
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
# We want to figure out a way to figure out what % of people in each country know python
country_respondant = df['Country'].value_counts()
country_respondant
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Tonga                        1
# Brunei Darussalam            1
# Saint Kitts and Nevis        1
# Dominica                     1
# Niger                        1
# Name: Country, Length: 179, dtype: int64

# %%
country_uses_python = country_group['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %% [markdown]
# Now we have to merge the above two

# %%
# Let us concatenate
python_df = pd.concat([country_respondant, country_uses_python], axis='columns', sort=False)
python_df
# Out:
#                        Country  LanguageWorkedWith
# United States            20949               10083
# India                     9061                3105
# Germany                   5866                2451
# United Kingdom            5737                2384
# Canada                    3395                1558
# ...                        ...                 ...
# Tonga                        1                   0
# Brunei Darussalam            1                   0
# Saint Kitts and Nevis        1                   0
# Dominica                     1                   1
# Niger                        1                   1
#
# [179 rows x 2 columns]

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df
# Out:
#                        NumRespondents  NumKnowsPython
# United States                   20949           10083
# India                            9061            3105
# Germany                          5866            2451
# United Kingdom                   5737            2384
# Canada                           3395            1558
# ...                               ...             ...
# Tonga                               1               0
# Brunei Darussalam                   1               0
# Saint Kitts and Nevis               1               0
# Dominica                            1               1
# Niger                               1               1
#
# [179 rows x 2 columns]

# %% [markdown]
# Calculating Percentage using formula

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df
# Out:
#                        NumRespondents  NumKnowsPython  PctKnowsPython
# United States                   20949           10083       48.131176
# India                            9061            3105       34.267741
# Germany                          5866            2451       41.783157
# United Kingdom                   5737            2384       41.554820
# Canada                           3395            1558       45.891016
# ...                               ...             ...             ...
# Tonga                               1               0        0.000000
# Brunei Darussalam                   1               0        0.000000
# Saint Kitts and Nevis               1               0        0.000000
# Dominica                            1               1      100.000000
# Niger                               1               1      100.000000
#
# [179 rows x 3 columns]

# %% [markdown]
# Let us sort thhem with countries highly knowing python

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)
# Out:
#                                   NumRespondents  NumKnowsPython  \
# Niger                                          1               1
# Dominica                                       1               1
# Sao Tome and Principe                          1               1
# Timor-Leste                                    1               1
# Turkmenistan                                   7               6
# Mauritania                                     7               5
# Bahamas                                        3               2
# Guinea                                         3               2
# Guyana                                         3               2
# Uganda                                        72              47
# Iceland                                       49              30
# Benin                                          5               3
# Haiti                                          5               3
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents    391.000000
# NumKnowsPython    182.000000
# PctKnowsPython     46.547315
# Name: Japan, dtype: float64
